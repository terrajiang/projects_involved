# %% [markdown]
# # GPT5-mini text generation (rewriting Gemini 3.5 Flash answers)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import pandas as pd

import os
import json

from google.colab import drive, userdata
from openai import OpenAI

# %% [markdown]
# ### Set up Google Drive mounting and define input/output paths:

# %%
# Mount the google drive folder
drive.mount('/content/drive', force_remount = True) # force reconnection

# Define directory, input, and output paths
project_directory = "/content/drive/MyDrive/Colab Notebooks/DS266/final_project"
input_file = os.path.join(project_directory, "data/everything_but_reddit_unstandardized_with_kimi.parquet")
output_file = os.path.join(project_directory, "data/gpt data/gpt5mini_gemini.jsonl")

# Ensure the output directory exists
if not os.path.exists(project_directory):
  os.makedirs(project_directory)

# Get access to the seceret api key
os.environ["OPENAI_API_KEY"] = userdata.get('HC3_GPT5mini')
client = OpenAI()
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Read the input file:

# %%
# Parquet file
df = pd.read_parquet(input_file)
print('Sucessfully read the input file with the questions and original answers!')

print(f'The input file contains {len(df)} records/rows.')
print(f'Column names: {list(df.columns)}')

print('\nThe first 5 rows:')
display(df.head())
# Out:
# Sucessfully read the input file with the questions and original answers!
# The input file contains 5306 records/rows.
# Column names: ['question', 'human_answers', 'source', 'gemini_answers', 'gpt5mini_answer', 'claude_haiku_4.5', 'kimi_k2_answers']
#
# The first 5 rows:
#                                  question  \
# 0           what composer used sound mass
# 1    where did the persian war take place
# 2                        what are add ons
# 3                 how does a dredge work?
# 4  what classes are considered humanities
#
#                                        human_answers   source  \
# 0  ['Composers and works include Barbara Kolb , P...  open_qa
# 1  ['The Greco-Persian Wars (also often called th...  open_qa
# 2  ['Plug-in (computing) , a piece of software wh...  open_qa
# 3  ['Dredging is an excavation activity or operat...  open_qa
# 4  ['The humanities are academic disciplines that...  open_qa
#
#                                       gemini_answers  \
# 0  The most prominent composer strongly associate...
# 1  The Persian Wars primarily took place in **mai...
# 2  An **add-on** is something extra or additional...
# 3  A dredge is essentially a floating machine des...
# 4  The humanities are academic disciplines that s...
#
#                                      gpt5mini_answer  \
# 0  Several 20th-century composers used the "sound...
# 1  If you mean the Greco–Persian Wars (often call...
# 2  "Add-ons" (sometimes written "add ons", "addon...
# 3  A dredge is a machine used to remove sediment,...
# 4  Humanities are academic disciplines that study...
#
#                                     claude_haiku_4.5  \
# 0  # Composers Who Used Sound Mass\n\n**Gyorgy Li...
# 1  # The Persian Wars\n\nThe Persian Wars took pl...
# 2  # Add-ons\n\nAdd-ons are **additional features...
# 3  # How a Dredge Works\n\nA dredge is a vessel o...
# 4  # Humanities Classes\n\nHumanities typically i...
#
#                                      kimi_k2_answers
# 0  The term **"sound mass"** (or **"sound-mass co...
# 1  The **Persian Wars** (also called the **Greco-...
# 2  **Add-ons** are extra software components or e...
# 3  A **dredge** is a machine or system designed t...
# 4  “Humanities” is the broad family of discipline...

# %% [markdown]
# ### Print the sample question and LLM answer:

# %%
print('Sample question:')
display(df['question'][0])

print('\nSample Gemini original answer:')
display(df['gemini_answers'][0])
# Out:
# Sample question:
# 'what composer used sound mass'
# Sample Gemini original answer:
# "The most prominent composer strongly associated with the technique of **sound mass** is **György Ligeti**.\\n\\nLigeti famously developed **micropolyphony**, where dense clusters of individual lines moving at different speeds create a shimmering, often static or slowly evolving, sonic texture. Works like *Atmosphères*, *Lontano*, and the Kyrie from his *Requiem* are prime examples.\\n\\nAnother crucial composer who extensively used sound mass, particularly in his early works, is **Krzysztof Penderecki**. His *Threnody to the Victims of Hiroshima* is an iconic piece that employs extended techniques (such as specific bowing instructions, glissandi, and tone clusters) to create vast, often unsettling, blocks of sound.\\n\\n**Iannis Xenakis** also created music that relies on dense sonic textures and stochastic processes, which often result in a form of sound mass, though perhaps with a more raw, architectural quality than Ligeti's or Penderecki's. Pieces like *Metastaseis* and *Pithoprakta* demonstrate this.\\n\\nSo, the key names are:\\n*   **György Ligeti**\\n*   **Krzysztof Penderecki**\\n*   **Iannis Xenakis**"

# %% [markdown]
# ### Rewrite Gemini 3.5 Flash answers in the new column `gpt5mini_gemini`:

# %%
# Look for where the generation was left off

last_row_id = -1

if os.path.exists(output_file):
  output_df = pd.read_json(output_file, lines = True) # JSONL
  last_row_id = output_df.index[-1]

print('No output file exists.' if last_row_id < 0 else f'Last row generated (row id): {last_row_id}')
# Out:
# Last row generated (row id): 5305

# %%
# Start appending to the file from where it's left off

with open(output_file, 'a') as f:

  # Keep track no-answer rows
  no_answer = 0

  # Iterate through each record/row
  for i, row in df.iterrows():

    # Print that the generation is already done if no rows are left to be generated
    if i == len(df) - 1:
      print(f'GPT5-mini {len(df)} answer generations already completed!')

    # Continue if current row is less than or equal to last_row_id
    if i <= last_row_id:
      continue

    # Convert each row to dictionary becasue the output file is going to be json
    row = row.to_dict()

    # Get the original answer to be rewritten
    original = row['gemini_answers']

    # Generate response from GPT-5mini
    try:
      gpt5mini_response = client.chat.completions.create(model = 'gpt-5-mini',
                                                         messages = [{'role': 'user', 'content': f"Refine the following text:\n\n{original}\n\nOutput only the rewritten text, nothing else."}],
                                                         max_completion_tokens = 1024,
                                                         reasoning_effort = 'low')  # Increase efficiency and comparability between models
      gpt5mini_answer = gpt5mini_response.choices[0].message.content

    except Exception as e:
      print(f'Error when processing row {i + 1} (index + 1) answer: {e}')
      no_answer += 1
      gpt5mini_answer = None

    # Insert the GPT-5mini answers into the dictionary (each row has a new column in the output file)
    row['gpt5mini_gemini'] = gpt5mini_answer

    # Write the row with new column into the output file
    f.write(json.dumps(row) + '\n')   # '\n' so that each row starts with a new line


    # Print out the progress when generating
    if i % 100 == 0:

      # Force writing to the os in case the program crashes
      f.flush()
      os.fsync(f.fileno())

      # Print the progress and saving status
      if i != 0 and (i - last_row_id) > 100:
        print('Finished and saved!')
      print(f'Start generating 100 answers for batch {(i // 100) + 1} ....', end = ' ')

    elif i == len(df) - 1:
      print(f'Finished {len(df)} answer generations!')
# Out:
# GPT5-mini 5306 answer generations already completed!

# %%
# Convert JSONL to CSV
out_df = pd.read_json(output_file, lines = True)

output_file_csv = os.path.join(project_directory, 'data/gpt data/gpt5mini_gemini.csv')
out_df.to_csv(output_file_csv, index = False)

# %% [markdown]
# ### Read the output file after rewriting:

# %%
out_df = pd.read_csv(output_file_csv)
print('Sucessfully read the output file with GPT5-mini rewriting answers!')

print(f'The output file contains {len(out_df)} records/rows.')
print(f'New column names: {list(out_df.columns)}')

print('\nThe first 5 rows:')
display(out_df.head())
# Out:
# Sucessfully read the output file with GPT5-mini rewriting answers!
# The output file contains 5306 records/rows.
# New column names: ['question', 'human_answers', 'source', 'gemini_answers', 'gpt5mini_answer', 'claude_haiku_4.5', 'kimi_k2_answers', 'gpt5mini_gemini']
#
# The first 5 rows:
#                                  question  \
# 0           what composer used sound mass
# 1    where did the persian war take place
# 2                        what are add ons
# 3                 how does a dredge work?
# 4  what classes are considered humanities
#
#                                        human_answers   source  \
# 0  ['Composers and works include Barbara Kolb , P...  open_qa
# 1  ['The Greco-Persian Wars (also often called th...  open_qa
# 2  ['Plug-in (computing) , a piece of software wh...  open_qa
# 3  ['Dredging is an excavation activity or operat...  open_qa
# 4  ['The humanities are academic disciplines that...  open_qa
#
#                                       gemini_answers  \
# 0  The most prominent composer strongly associate...
# 1  The Persian Wars primarily took place in **mai...
# 2  An **add-on** is something extra or additional...
# 3  A dredge is essentially a floating machine des...
# 4  The humanities are academic disciplines that s...
#
#                                      gpt5mini_answer  \
# 0  Several 20th-century composers used the "sound...
# 1  If you mean the Greco–Persian Wars (often call...
# 2  "Add-ons" (sometimes written "add ons", "addon...
# 3  A dredge is a machine used to remove sediment,...
# 4  Humanities are academic disciplines that study...
#
#                                     claude_haiku_4.5  \
# 0  # Composers Who Used Sound Mass\n\n**Gyorgy Li...
# 1  # The Persian Wars\n\nThe Persian Wars took pl...
# 2  # Add-ons\n\nAdd-ons are **additional features...
# 3  # How a Dredge Works\n\nA dredge is a vessel o...
# 4  # Humanities Classes\n\nHumanities typically i...
#
#                                      kimi_k2_answers  \
# 0  The term **"sound mass"** (or **"sound-mass co...
# 1  The **Persian Wars** (also called the **Greco-...
# 2  **Add-ons** are extra software components or e...
# 3  A **dredge** is a machine or system designed t...
# 4  “Humanities” is the broad family of discipline...
#
#                                      gpt5mini_gemini
# 0  The composer most strongly associated with the...
# 1  The Persian Wars were fought mainly in mainlan...
# 2  An add-on is an optional extra—something attac...
# 3                                                NaN
# 4  The humanities are academic disciplines that e...

# %% [markdown]
# ### Print the sample question and Gemini 3.5 Flash answers:

# %%
print('Sample question:')
display(out_df['question'].iloc[-1])

print('\nSample Gemini original answer:')
display(out_df['gemini_answers'].iloc[-1])
print('\nSample Gemini answer rewritten by GPT5-mini:')
display(out_df['gpt5mini_gemini'].iloc[-1])
# Out:
# Sample question:
# 'Are BP of 119/65 and pulse of 35 causes for concern?Yesterday I was very dizzy, short of breath, heart rate around 35,BP 119/65. I am 51,female, overweight and have RA and Fibermyalgia. Do you know what might have caused this episode yesterday? I figure I would not feel okay today if it had been a heart attack.'
# Sample Gemini original answer:
# 'Yes, your blood pressure of 119/65 is generally considered healthy, but **a pulse of 35 bpm (beats per minute) combined with dizziness and shortness of breath is a significant cause for concern and warrants immediate medical attention.**\\n\\nHere\'s a breakdown of your situation:\\n\\n1.  **Pulse of 35 bpm:** A normal resting heart rate for adults is typically between 60 and 100 bpm. A heart rate of 35 bpm is called **severe bradycardia** (abnormally slow heart rate). When your heart beats this slowly, it may not be able to pump enough oxygen-rich blood to your body, especially your brain, which explains your dizziness and shortness of breath. This can be dangerous as it can lead to fainting, falls, and potentially more serious cardiac issues.\\n\\n2.  **BP of 119/65:** While this blood pressure reading is within a healthy range, in the context of a severely low heart rate and symptoms like dizziness and shortness of breath, it suggests that your heart is struggling to maintain adequate blood flow despite a \\"normal\\" pressure. Your body might be trying to compensate for the slow heart rate, but it\'s clearly not enough given your symptoms.\\n\\n3.  **Dizziness and Shortness of Breath:** These are classic symptoms of inadequate blood flow to the brain and other organs, which can be directly caused by severe bradycardia.\\n\\n4.  **Your Medical History (RA, Fibromyalgia, Overweight, 51/Female):**\\n    *   **RA (Rheumatoid Arthritis):** While primarily affecting joints, RA is a systemic inflammatory disease that can sometimes affect the heart (e.g., pericarditis, myocarditis, increased risk of atherosclerosis). Medications for RA could also potentially affect heart rhythm, though this is less common.\\n    *   **Overweight:** This is a risk factor for various heart conditions, including sleep apnea (which can sometimes cause bradycardia), hypertension, and other cardiovascular issues.\\n    *   **Age/Gender:** While not directly causing bradycardia, your age and gender put you in a demographic where various cardiovascular issues can arise.\\n\\n**What might have caused this episode?**\\n\\nGiven your symptoms and very low pulse, the most likely causes relate to issues with your heart\'s electrical system, which controls its rhythm. Potential causes for severe bradycardia include:\\n\\n*   **Heart Conduction Problems (e.g., Heart Block):** This is when electrical signals that tell your heart to beat are slowed or blocked as they travel through the heart. This is a very common cause of symptomatic bradycardia.\\n*   **Sick Sinus Syndrome:** A malfunction of the heart\'s natural pacemaker (the sinus node).\\n*   **Medication Side Effects:** Certain medications, especially those for high blood pressure or heart conditions (e.g., beta-blockers, calcium channel blockers, digoxin), can slow the heart rate too much. Even medications for other conditions can sometimes have this effect. Have you started any new medications or had a dosage change recently?\\n*   **Electrolyte Imbalances:** Levels of potassium, calcium, or magnesium that are too high or too low can affect heart rhythm.\\n*   **Thyroid Issues:** An underactive thyroid (hypothyroidism) can sometimes lead to a slower heart rate.\\n*   **Sleep Apnea:** Particularly common in overweight individuals'
# Sample Gemini answer rewritten by GPT5-mini:
# 'Yes — your blood pressure of 119/65 is generally healthy, but a pulse of 35 bpm combined with dizziness and shortness of breath is a serious concern and requires immediate medical attention.\n\nSummary of your situation\n\n1. Pulse 35 bpm: A normal resting heart rate for adults is usually 60–100 bpm. A heart rate of 35 bpm is severe bradycardia. At this rate the heart may not pump enough oxygenated blood to the body and brain, which explains dizziness and shortness of breath. Severe bradycardia can lead to fainting, falls, and more serious cardiac complications.\n\n2. Blood pressure 119/65: This is within a normal range, but in the context of marked bradycardia and symptoms it does not rule out inadequate tissue perfusion. The body may be compensating, but your symptoms indicate that compensation is insufficient.\n\n3. Dizziness and shortness of breath: These are classic signs of reduced blood flow to the brain and other organs and are consistent with symptomatic bradycardia.\n\n4. Relevant history (51, female; RA; fibromyalgia; overweight): \n   - Rheumatoid arthritis is an inflammatory, systemic disease that can affect the heart (for example, pericarditis or myocarditis) and is associated with higher cardiovascular risk. Some RA medications can also influence heart rhythm.\n   - Overweight status increases risk for conditions such as sleep apnea, hypertension, and other cardiovascular disease that can contribute to rhythm problems.\n   - Age and sex influence cardiovascular risk profiles and should be considered.\n\nPossible causes of this episode\n\n- Heart conduction system problems (e.g., heart block) that slow or interrupt electrical signals.\n- Sick sinus syndrome (malfunction of the sinus node, the heart’s natural pacemaker).\n- Medication effects: beta-blockers, some calcium channel blockers, digoxin, and other drugs can cause bradycardia. Have you started any new medications or had recent dose changes?\n- Electrolyte abnormalities (potassium, calcium, magnesium).\n- Hypothyroidism.\n- Sleep apnea (more common with overweight).\n\nBecause a pulse of 35 bpm with dizziness and shortness of breath can be life-threatening, seek urgent medical evaluation right away (emergency department or call emergency services). Medical providers can obtain an ECG, monitor your rhythm, check electrolytes and thyroid function, review medications, and begin appropriate treatment.'

# %% [markdown]
# ### Check NaN counts

# %%
pd.isna(out_df['gpt5mini_gemini']).value_counts()
# Out:
# gpt5mini_gemini
# False    5178
# True      128
# Name: count, dtype: int64
