# %% [markdown]
# # Project 3 - Create and load table for Illegal Ivory Trade

# %% [markdown]
# ### Running PageRank on the first graph.
#     Who are the most influential importing countries?

# %%
import csv

import math
import numpy as np
import pandas as pd

import psycopg2

# %%
# function to run a select query and return rows in a pandas dataframe
# pandas puts all numeric values from postgres to float
# if it will fit in an integer, change it to integer
#

def my_select_query_pandas(query, rollback_before_flag, rollback_after_flag):
    "function to run a select query and return rows in a pandas dataframe"
    
    if rollback_before_flag:
        connection.rollback()
    
    df = pd.read_sql_query(query, connection)
    
    if rollback_after_flag:
        connection.rollback()
    
    # fix the float columns that really should be integers
    
    for column in df:
    
        if df[column].dtype == "float64":

            fraction_flag = False

            for value in df[column].values:
                
                if not np.isnan(value):
                    if value - math.floor(value) != 0:
                        fraction_flag = True

            if not fraction_flag:
                df[column] = df[column].astype('Int64')
    
    return(df)

# %%
connection = psycopg2.connect(
    user = "postgres",
    password = "ucb",
    host = "postgres",
    port = "5432",
    database = "postgres"
)

# %%
cursor = connection.cursor()

# %%
def my_read_csv_file(file_name, limit):
    "read the csv file and print only the first limit rows"
    
    csv_file = open(file_name, "r")
    
    csv_data = csv.reader(csv_file)
    
    i = 0
    
    for row in csv_data:
        i += 1
        if i <= limit:
            print(row)
            
    print("\nPrinted ", min(limit, i), "lines of ", i, "total lines.")

# %% [markdown]
# # Consolidation for 51 csv files with ~500,000 entries each.

# %%
# # # DO NOT RUN CELL AGAIN... TAKES A LONG TIME...
# # Combine csv files into one 

# file_list = [f'/user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_{i}.csv' for i in range(5, 52)]
# output_file = '/user/projects/project-3-shengminx/data/ivory_trade.csv'

# # Set to True so the header is only written once
# first = True


# chunk_size = 100000  # adjust if needed

# for file in file_list:
#     print(f"Processing: {file}")
#     try:
#         for chunk in pd.read_csv(file, dtype=str, engine='python', chunksize=chunk_size):
#             chunk.to_csv(output_file, mode='a', index=False, header=first)
#             first = False
#     except Exception as e:
#         print(f"Error reading {file}: {e}")
# Out:
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_5.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_6.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_7.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_8.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_9.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_10.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_11.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_12.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_13.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_14.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_15.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_16.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_17.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_18.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_19.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_20.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_21.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_22.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_23.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_24.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_25.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_26.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_27.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_28.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_29.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_30.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_31.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_32.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_33.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_34.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_35.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_36.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_37.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_38.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_39.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_40.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_41.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_42.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_43.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_44.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_45.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_46.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_47.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_48.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_49.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_50.csv
# Processing: /user/projects/project-3-shengminx/data/Trade_database_download_v2023.1/trade_db_51.csv

# %%
my_read_csv_file('/user/projects/project-3-shengminx/data/ivory_trade.csv', 10)
# Out:
# ['Id', 'Year', 'Appendix', 'Taxon', 'Class', 'Order', 'Family', 'Genus', 'Term', 'Quantity', 'Unit', 'Importer', 'Exporter', 'Origin', 'Purpose', 'Source', 'Reporter.type', 'Import.permit.RandomID', 'Export.permit.RandomID', 'Origin.permit.RandomID']
# ['779124505', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '11', '', 'AT', 'ID', '', 'T', 'W', 'I', '', '695114dbf3', '']
# ['736178525', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '5', '', 'DE', 'ID', '', 'T', 'W', 'I', '0b96462380', '33c8b7b223', '']
# ['513454525', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '5', '', 'DE', 'ID', '', 'T', 'W', 'I', '859233900b', '04c82c7a7b', '']
# ['601075995', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '5', '', 'DE', 'ID', '', 'T', 'W', 'I', '957c7a20e5', '6b3376e2ce', '']
# ['313595725', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '5', '', 'DE', 'ID', '', 'T', 'W', 'I', '51c0ea3d6b', '5d5ecf15bb', '']
# ['979117825', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '5', '', 'DE', 'ID', '', 'T', 'W', 'I', '13a5a013bd', 'aac2fd94a2', '']
# ['717463085', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '11', '', 'DE', 'ID', '', 'T', 'W', 'I', '5682b6d89d', '63182b53c1', '']
# ['557344485', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '10', '', 'DE', 'ID', '', 'T', 'W', 'I', '561eb5bcdf', '71d44aa681', '']
# ['212870465', '2003', 'II', 'Acanthastrea echinata', 'Anthozoa', 'Scleractinia', 'Mussidae', 'Acanthastrea', 'live', '8', '', 'FR', 'ID', '', 'T', 'W', 'I', 'd8d62c0881', '51147f70e0', '']
#
# Printed  10 lines of  23021291 total lines.

# %% [markdown]
# # Drop Table If Exist

# %%
connection.rollback()

query = """

drop table if exists ivory_trade;

"""

cursor.execute(query)

connection.commit()

# %% [markdown]
# # Create Table ivory_trade

# %%
connection.rollback()

query = """

create table ivory_trade (

  Id bigint primary key,
  Year integer,
  Appendix varchar(5),
  Taxon text,
  Class varchar(100),
  "Order" varchar(100),
  Family varchar(100),
  Genus varchar(100),
  Term varchar(50),
  Quantity numeric,
  Unit varchar(20),
  Importer char(2),
  Exporter char(2),
  Origin char(2),
  Purpose varchar(10),
  Source varchar(10),
  Reporter_type varchar(20),
  Import_permit_RandomID varchar(64),
  Export_permit_RandomID varchar(64),
  Origin_permit_RandomID varchar(64)

);

"""

cursor.execute(query)

connection.commit()

# %% [markdown]
# # Load csv files to database table

# %%
connection.rollback()

query = """

copy ivory_trade
from '/user/projects/project-3-shengminx/data/ivory_trade.csv' delimiter ',' NULL '' csv header;

"""

cursor.execute(query)

connection.commit()

# %% [markdown]
# # Check Table

# %%
rollback_before_flag = True
rollback_after_flag = True

query = """

select *
from ivory_trade
limit 10

"""

my_select_query_pandas(query, rollback_before_flag, rollback_after_flag)
# Out:
#           id  year appendix                  taxon     class         Order  \
# 0  779124505  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 1  736178525  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 2  513454525  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 3  601075995  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 4  313595725  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 5  979117825  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 6  717463085  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 7  557344485  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 8  212870465  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
# 9  989226655  2003       II  Acanthastrea echinata  Anthozoa  Scleractinia
#
#      family         genus  term  quantity  unit importer exporter origin  \
# 0  Mussidae  Acanthastrea  live        11  None       AT       ID   None
# 1  Mussidae  Acanthastrea  live         5  None       DE       ID   None
# 2  Mussidae  Acanthastrea  live         5  None       DE       ID   None
# 3  Mussidae  Acanthastrea  live         5  None       DE       ID   None
# 4  Mussidae  Acanthastrea  live         5  None       DE       ID   None
# 5  Mussidae  Acanthastrea  live         5  None       DE       ID   None
# 6  Mussidae  Acanthastrea  live        11  None       DE       ID   None
# 7  Mussidae  Acanthastrea  live        10  None       DE       ID   None
# 8  Mussidae  Acanthastrea  live         8  None       FR       ID   None
# 9  Mussidae  Acanthastrea  live         4  None       ES       ID   None
#
#   purpose source reporter_type import_permit_randomid export_permit_randomid  \
# 0       T      W             I                   None             695114dbf3
# 1       T      W             I             0b96462380             33c8b7b223
# 2       T      W             I             859233900b             04c82c7a7b
# 3       T      W             I             957c7a20e5             6b3376e2ce
# 4       T      W             I             51c0ea3d6b             5d5ecf15bb
# 5       T      W             I             13a5a013bd             aac2fd94a2
# 6       T      W             I             5682b6d89d             63182b53c1
# 7       T      W             I             561eb5bcdf             71d44aa681
# 8       T      W             I             d8d62c0881             51147f70e0
# 9       T      W             I                   None             bfeabf81bb
#
#   origin_permit_randomid
# 0                   None
# 1                   None
# 2                   None
# 3                   None
# 4                   None
# 5                   None
# 6                   None
# 7                   None
# 8                   None
# 9                   None
